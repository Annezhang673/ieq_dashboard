# %%
import utility as util
from datetime import datetime, timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('book_with_grids.csv')
current_time = datetime.now()
current_utc = current_time + timedelta(days=0, hours=5)

start = current_utc - timedelta(days=0, hours=0, minutes=15)
end = current_utc

# %%
current_time
# Out:
# datetime.datetime(2022, 12, 2, 14, 58, 10, 510151)

# %%
grid = 139
readings_co2 = util.get_lfdf("co2_ppm",start,end,list(df[df["grid"]==grid]["device_id"]))
readings_temp = util.get_lfdf("Temperature_°C",start,end,list(df[df["grid"]==grid]["device_id"]))
readings_ill = util.get_lfdf("Illumination_lx",start,end,list(df[df["grid"]==grid]["device_id"]))

print ('\n \n \n')
print('--------- location ---------')
print('co2 device location:')
print('does not exit' if readings_co2 is None else set(readings_co2['location_specific']))
print ('\n')
print('temp device location:')
print('does not exit' if readings_temp is None else set(readings_temp['location_specific']))
print ('\n')
print('ill device location:')
print('does not exit' if readings_ill is None else set(readings_ill['location_specific']))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): influx.linklab.virginia.edu:443
# c:\Users\Blake\.conda\envs\probe\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'influx.linklab.virginia.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# DEBUG:urllib3.connectionpool:https://influx.linklab.virginia.edu:443 "GET /query?q=SELECT+%2A+FROM+%22co2_ppm%22+WHERE+time+%3E%3D+%272022-12-02+19%3A43%3A10%27+and+time+%3C+%272022-12-02+19%3A58%3A10%27and+%28%22device_id%22%3D%27050621a8%27or+%22device_id%22%3D%27018a29cc%27or+%22device_id%22%3D%27050d69ce%27or+%22device_id%22%3D%27018342dc%27or+%22device_id%22%3D%2770886b123039%27%29&db=gateway-generic HTTP/1.1" 200 None
# Retrieving client for: gateway-generic
# start_time: 2022-12-02 19:43:10
# end_time: 2022-12-02 19:58:10
# ...

# %%
readings_co2
# Out:
#                         time     0     1     2     3 awair_device_uuid  \
# 0  2022-12-02 14:43:18-05:00  None  None  None  None  awair-omni_12958
# 1  2022-12-02 14:43:28-05:00  None  None  None  None  awair-omni_12958
# 2  2022-12-02 14:43:39-05:00  None  None  None  None  awair-omni_12958
# 3  2022-12-02 14:43:49-05:00  None  None  None  None  awair-omni_12958
# 4  2022-12-02 14:43:59-05:00  None  None  None  None  awair-omni_12958
# ..                       ...   ...   ...   ...   ...               ...
# 84 2022-12-02 14:57:21-05:00  None  None  None  None  awair-omni_12958
# 85 2022-12-02 14:57:31-05:00  None  None  None  None  awair-omni_12958
# 86 2022-12-02 14:57:41-05:00  None  None  None  None  awair-omni_12958
# 87 2022-12-02 14:57:51-05:00  None  None  None  None  awair-omni_12958
# 88 2022-12-02 14:58:01-05:00  None  None  None  None  awair-omni_12958
#
#    awair_mac_address description details device_class     device_id  \
# ...

# %%
target_locaiton = '243 Olsson'

if readings_co2 is not None:
    readings_co2 = readings_co2[readings_co2['location_specific']
                                == target_locaiton]
    print('co2 device id:')
    print(set(readings_co2['device_id']))

print('\n')
if readings_temp is not None:
    readings_temp = readings_temp[readings_temp['location_specific']
                                  == target_locaiton]
    print('temp device id:')
    print(set(readings_temp['device_id']))

print('\n')
if readings_ill is not None:
    readings_ill = readings_ill[readings_ill['location_specific']
                                  == target_locaiton]
    print('temp device id:')
    print(set(readings_ill['device_id']))
# Out:
# temp device id:
# {'018a2e6d'}

# %%
id = ['70886b123039']

readings_co2 = util.get_lfdf("co2_ppm",start,end,id)
readings_temp = util.get_lfdf("Temperature_°C",start,end,id)
readings_ill = util.get_lfdf("Illumination_lx",start,end,id)

print ('\n \n \n')
print('--------- location ---------')
print('co2 device location:')
print('does not exit' if readings_co2 is None else set(readings_co2['location_specific']))
print ('\n')
print('temp device location:')
print('does not exit' if readings_temp is None else set(readings_temp['location_specific']))
print ('\n')
print('ill device location:')
print('does not exit' if readings_ill is None else set(readings_ill['location_specific']))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): influx.linklab.virginia.edu:443
# c:\Users\Blake\.conda\envs\probe\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'influx.linklab.virginia.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# DEBUG:urllib3.connectionpool:https://influx.linklab.virginia.edu:443 "GET /query?q=SELECT+%2A+FROM+%22co2_ppm%22+WHERE+time+%3E%3D+%272022-12-02+23%3A22%3A14%27+and+time+%3C+%272022-12-02+23%3A37%3A14%27and+%28%22device_id%22%3D%2770886b123039%27%29&db=gateway-generic HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): influx.linklab.virginia.edu:443
# Retrieving client for: gateway-generic
# start_time: 2022-12-02 23:22:14
# end_time: 2022-12-02 23:37:14
# Retrieving client for: gateway-generic
# ...
